# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных</a></span><ul class="toc-item"><li><span><a href="#Обзор" data-toc-modified-id="Обзор-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обзор</a></span></li><li><span><a href="#Проверка-эффективности-обогащения" data-toc-modified-id="Проверка-эффективности-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка эффективности обогащения</a></span></li><li><span><a href="#Признаки,-недоступные-в-тестовой-выборке" data-toc-modified-id="Признаки,-недоступные-в-тестовой-выборке-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Признаки, недоступные в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Динамика-концентрации-металлов" data-toc-modified-id="Динамика-концентрации-металлов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Динамика концентрации металлов</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Распределение-размеров-гранул-сырья" data-toc-modified-id="Распределение-размеров-гранул-сырья-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья</a></span><ul class="toc-item"><li><span><a href="#Флотация" data-toc-modified-id="Флотация-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Флотация</a></span></li><li><span><a href="#Первичная-очистка" data-toc-modified-id="Первичная-очистка-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Первичная очистка</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Выделение-признаков" data-toc-modified-id="Выделение-признаков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выделение признаков</a></span></li><li><span><a href="#Проведем-обучение-моделей" data-toc-modified-id="Проведем-обучение-моделей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проведем обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Catboost" data-toc-modified-id="Catboost-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Catboost</a></span></li><li><span><a href="#Lasso" data-toc-modified-id="Lasso-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Lasso</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Тестирование модели</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Предсказание коэффициента восстановления золота из золотосодержащей руды

# %% [markdown]
# ## Описание проекта
#
# Компания-заказчик: "Цифра" (zyfra.com)
# Задача: подготовить прототип модели машинного обучения.
#
# Компания разрабатывает решения для эффективной работы промышленных предприятий.
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
#
# Данные: параметры добычи и очистки.
#
# Цель исследования: с помощью модели оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Ход исследования:
#
# Подготовка данных;
# Исследовательский анализ данных;
# Построение и обучение модели.
# Расчёт эффективности
#
# Необходимо: смоделировать процесс восстановления золота из золотосодержащей руды.
# Эффективность обогащения рассчитывается по формуле
#
# ![image.png](attachment:image.png)
#
# где:
#     •	C — доля золота в концентрате после флотации/очистки;
#     •	F — доля золота в сырье/концентрате до флотации/очистки;
#     •	T — доля золота в отвальных хвостах после флотации/очистки.
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# Метрика качества
#
# Для решения задачи использована метрика качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Аналог MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания:
#
# ![image.png](attachment:image.png)
#
#
# Обозначения:
# ![image-2.png](attachment:image-2.png)
#
#             Значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество.
# ![image-3.png](attachment:image-3.png)
#
#                   Значение предсказания для объекта с порядковым номером i, например, в тестовой выборке.
#
# ![image-4.png](attachment:image-4.png)
#
#                                                   Количество объектов в выборке.
#
# ![image-5.png](attachment:image-5.png)
#
#                                  Суммирование по всем объектам выборки (i меняется от 1 до N).
#
#
# Нужно спрогнозировать сразу две величины:
# 1.	эффективность обогащения чернового концентрата rougher.output.recovery;
# 2.	эффективность обогащения финального концентрата final.output.recovery.
#
# Итоговая метрика складывается из двух величин:
# ![image-6.png](attachment:image-6.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go

from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.dummy import DummyRegressor

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline

from scipy import stats as st

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# ### Обзор

# %%
try:
    full = pd.read_csv(r'C:\Users\artfo\Documents\yandex_practicum\projects\9_zyfra.com_integrated\gold_recovery_full_new.csv')
    train = pd.read_csv(r'C:\Users\artfo\Documents\yandex_practicum\projects\9_zyfra.com_integrated\gold_recovery_train_new.csv')
    test = pd.read_csv(r'C:\Users\artfo\Documents\yandex_practicum\projects\9_zyfra.com_integrated\gold_recovery_test_new.csv')
except:
    full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
    train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %%
#ф-я для общего обзора
df_names = ['Gold recovery full', 'Gold recovery train', 'Gold recovery test']
dfs = [full, train, test]

def df_info(df):
    display(df.info())
    display(df.head())

# %%
#ф-я для обзора пропусков и дубликатов
def checker(df):
    print('Пропуски')
    display(df.isna().sum().sort_values(ascending=False))
    print('Дубликатов')
    display(df.duplicated().sum())
    print('_'*60)

# %%
for df, name in zip(dfs, df_names):
    print(name)
    df_info(df)
# Out:
# Gold recovery full
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
for df, name in zip(dfs, df_names):
    print(name)
    checker(df)
# Out:
# Gold recovery full
# Пропуски
# secondary_cleaner.output.tail_sol                     1748
# rougher.input.floatbank11_xanthate                     453
# rougher.state.floatbank10_e_air                        436
# primary_cleaner.output.concentrate_sol                 370
# secondary_cleaner.state.floatbank2_a_air               220
# final.output.concentrate_sol                           211
# rougher.input.feed_size                                145
# primary_cleaner.output.concentrate_pb                  116
# primary_cleaner.input.xanthate                         104
# final.output.tail_pb                                   101
# rougher.input.feed_pb                                  100
# rougher.input.feed_sol                                  99
# primary_cleaner.output.tail_sol                         62
# rougher.input.floatbank11_sulfate                       44
# primary_cleaner.input.depressant                        37
# ...

# %% [markdown]
# ### Проверка эффективности обогащения

# %% [markdown]
# Перед предобработкой данных, убедимся, что эффективность обогащения рассчитана правильно. Вычислим этот показатель по предоставленной ваше формуле на обучающей выборке для признака rougher.output.recovery.

# %%
C = train['rougher.output.concentrate_au']
F = train['rougher.input.feed_au']
T = train['rougher.output.tail_au']
table_recovery = train['rougher.output.recovery']

my_recovery = ((C * (F - T)) / (F * (C - T))) * 100

MAE = mean_absolute_error(table_recovery, my_recovery)
MAE
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Средняя абсолютная ошибка между расчитанным значением и значением признака в таблице равна 9.73512347450521e-15, что является ничтожно малым значением, отсюда следует что показатель эффективности обогащения `rougher.output.recovery` рассчитан правильно.

# %% [markdown]
# ### Признаки, недоступные в тестовой выборке

# %%
print('Признаки, отсутствующие в тестовой выборке')
print('_'*50)
count = 0
train_columns_to_drop = []
for col in train.columns:
    if col not in test.columns:
        print(col)
        count += 1
    else:
        pass
print('Всего отсутствующих признаков:', count)
# Out:
# Признаки, отсутствующие в тестовой выборке
# __________________________________________________
# final.output.concentrate_ag
# final.output.concentrate_pb
# final.output.concentrate_sol
# final.output.concentrate_au
# final.output.recovery
# final.output.tail_ag
# final.output.tail_pb
# final.output.tail_sol
# final.output.tail_au
# primary_cleaner.output.concentrate_ag
# primary_cleaner.output.concentrate_pb
# primary_cleaner.output.concentrate_sol
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.tail_ag
# primary_cleaner.output.tail_pb
# primary_cleaner.output.tail_sol
# primary_cleaner.output.tail_au
# rougher.calculation.sulfate_to_au_concentrate
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.au_pb_ratio
# rougher.output.concentrate_ag
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.concentrate_au
# rougher.output.recovery
# rougher.output.tail_ag
# ...

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Посмотрим сколько и каких данных пропущено в тренировочной и тестовой выборках.

# %%
def pass_value(df): # пропущенные значения бары
    (
        (df.isna().mean()*100)
        .to_frame()
        .rename(columns = {0:'space'})
        .query('space > 0')
        .sort_values(by = 'space', ascending = False)
        .plot(kind= 'bar', figsize=(20,5))
    );

# %%
print('Пропуски в общей выборке')
pass_value(full)
# Out:
# Пропуски в общей выборке

# %%
large_pass_full = full[full.isna().sum().to_frame().sort_values(by=0, ascending=False).index[0]].isna().sum() / full.shape[0]
print(f'Процент максимального числа пропущенных значений от общего числа строк в общей выборке: {large_pass_full:.2%}')
# Out:
# Процент максимального числа пропущенных значений от общего числа строк в общей выборке: 8.99%

# %%
print('Пропуски в обучающей выборке')
pass_value(train)
# Out:
# Пропуски в обучающей выборке

# %%
large_pass_train = train[train.isna().sum().to_frame().sort_values(by=0, ascending=False).index[0]].isna().sum() / train.shape[0]
print(f'Процент максимального числа пропущенных значений от общего числа строк в обучающей выборке: {large_pass_train:.2%}')
# Out:
# Процент максимального числа пропущенных значений от общего числа строк в обучающей выборке: 11.34%

# %%
print('Пропуски в тестовой выборке')
pass_value(test)
# Out:
# Пропуски в тестовой выборке

# %%
large_pass_test = test[test.isna().sum().to_frame().sort_values(by=0, ascending=False).index[0]].isna().sum() / test.shape[0]
print(f'Процент максимального числа пропущенных значений от общего числа строк в тестовой выборке: {large_pass_test:.2%}')
# Out:
# Процент максимального числа пропущенных значений от общего числа строк в тестовой выборке: 0.47%

# %% [markdown]
# 11% и 9% пропущенных данных в общей и обучающей выборке - это много, поэтому дропнуть мы их не можем. При постановке задачи было указано, что "соседние по времени параметры часто похожи". Данные по умолчанию отсортированы по дате, поэтому мы можем заполнить пропуски в этих датасетах соседними значениями.
#
# Что касается тестовой выборки, процент пропусков составляет всего 0.47%, эти строки мы можем удалить.

# %%
full.fillna(method='ffill', inplace=True)
train.fillna(method='ffill', inplace=True)
test.dropna(inplace=True)

# %%
#check

for df, name in zip(dfs, df_names):
    print(name)
    print(df.isna().sum())
    print('_' * 55)
# Out:
# Gold recovery full
# date                                                  0
# final.output.concentrate_ag                           0
# final.output.concentrate_pb                           0
# final.output.concentrate_sol                          0
# final.output.concentrate_au                           0
# final.output.recovery                                 0
# final.output.tail_ag                                  0
# final.output.tail_pb                                  0
# final.output.tail_sol                                 0
# final.output.tail_au                                  0
# primary_cleaner.input.sulfate                         0
# primary_cleaner.input.depressant                      0
# primary_cleaner.input.feed_size                       0
# primary_cleaner.input.xanthate                        0
# primary_cleaner.output.concentrate_ag                 0
# primary_cleaner.output.concentrate_pb                 0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Были изучены анализируемые датасеты. В данных отсутствуеют дубликаты, но в ряде признаков во всех трех датасетах присутствуют пропуски, которые были обработаны (в общей и обучающей выборках заполнены соседними значениями (что допустимо в рамках условий задачи), в тестовой выборки удалены за счет своей малой доли от общего числа строк (менее 1%).
#
#
# 2. Была проведена проверка эффективности обогащения, найдена средняя абсолютная ошибка, которая оказалась ничтожно мала. Проверка показала, что показатель рассчитан верно.
#
#
# 3. В тестовой выборке отсутствуют параметры концентратов и отвальных хвостов металлов на всех этапах очистки. Данные признаки относятся к вычисляемому типу чисел с плавающей точкой и не будут использованы в модели.
#
#
# 4. В тестовой выборке отсутствовали целевые признаки, их мы добавим позже из полной выборки. Также удалим из обучающей выборки признаки, отсутствующие в тестовой.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Динамика концентрации металлов

# %% [markdown]
# Для начала посмотрим как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
# colors = ['#393E46', '#2BCDC1', '#F66095']
# group_labels = ["Флотация", "Первичная очистка", "Финальная стадия"]

# hist_data = [
#     train['rougher.output.concentrate_au'],
#     train['primary_cleaner.output.concentrate_au'],
#     train['final.output.concentrate_au']
# ]


# fig = ff.create_distplot(hist_data,
#                          group_labels,
#                          colors=colors)
# fig.update_layout(title_text='Динамика изменения концентрации Золота',
#                   xaxis_title="Concentration",
#                   yaxis_title="Count",)
# fig.show();

# %%
# hist_data = [
#     train['rougher.output.concentrate_ag'],
#     train['primary_cleaner.output.concentrate_ag'],
#     train['final.output.concentrate_ag']
# ]

# fig = ff.create_distplot(hist_data,
#                          group_labels,
#                          colors=colors,
#                          bin_size=.4)
# fig.update_layout(title_text='Динамика изменения концентрации Серебра',
#                   xaxis_title="Concentration",
#                   yaxis_title="Count",)
# fig.show();

# %%
# hist_data = [
#     train['rougher.output.concentrate_pb'],
#     train['primary_cleaner.output.concentrate_pb'],
#     train['final.output.concentrate_pb']
# ]

# fig = ff.create_distplot(hist_data,
#                          group_labels,
#                          colors=colors,
#                          bin_size=.5)
# fig.update_layout(title_text='Динамика изменения концентрации Свинца',
#                   xaxis_title="Concentration",
#                   yaxis_title="Count",)
# fig.show();

# %% [markdown]
# #### Вывод

# %% [markdown]
# Отчетливо видно, что с каждым новым этапом концентрация:
#
#     •золота - равномерно растет ✅ (является непосредственной целью)
#     •серебра - падает
#     •свинца - сильно растет от этапа флотации к первичной очистке

# %% [markdown]
# ### Распределение размеров гранул сырья

# %% [markdown]
# Сравним распределения размеров гранул сырья на обучающей и тестовой выборках на разных этапах

# %% [markdown]
# #### Флотация

# %%
# fig = go.Figure()
# fig.add_trace(go.Box(x=train['rougher.input.feed_size'],
#                      name='Обучающая',
#                      boxpoints='suspectedoutliers',
#                      jitter=.8,
#                      pointpos=1.2))
# fig.add_trace(go.Box(x=test['rougher.input.feed_size'],
#                      name='Тестовая',
#                      boxpoints='suspectedoutliers',
#                      jitter=.8,
#                      pointpos=-1.2))
# fig.update_layout(title_text='Распределение размеров гранул сырья (Флотация)')
# fig.show();

# %% [markdown]
# #### Первичная очистка

# %%
# fig = go.Figure()
# fig.add_trace(go.Box(x=train['primary_cleaner.input.feed_size'],
#                      name='Обучающая',
#                      boxpoints='suspectedoutliers',
#                      jitter=.8,
#                      pointpos=1.2))
# fig.add_trace(go.Box(x=test['primary_cleaner.input.feed_size'],
#                      name='Тестовая',
#                      boxpoints='suspectedoutliers',
#                      jitter=.8,
#                      pointpos=-1.2))
# fig.update_layout(title_text='Распределение размеров гранул сырья (Первичная очистка)')
# fig.show();

# %% [markdown]
# #### Вывод

# %% [markdown]
# Распределения размеров гранул сырья отличаются незначительно, достоверности оценки модели этот показатель не угрожает ✅

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях

# %% [markdown]
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах (на обучающей выборке)

# %%
# просуммируем концентрацию всех веществ

train['rougher_concentrate_total'] = train['rougher.output.concentrate_au'] + train['rougher.output.concentrate_ag'] + train['rougher.output.concentrate_pb'] + train['final.output.concentrate_sol']
train['rougher_input_feed_total'] = train['rougher.input.feed_au'] + train['rougher.input.feed_ag'] + train['rougher.input.feed_pb'] + train['rougher.input.feed_sol']
train['final_concentrate_total'] = train['final.output.concentrate_au'] + train['final.output.concentrate_ag'] + train['final.output.concentrate_pb'] + train['final.output.concentrate_sol']

# %%
# просуммируем концентрацию всех веществ

full['rougher_concentrate_total'] = full['rougher.output.concentrate_au'] + full['rougher.output.concentrate_ag'] + full['rougher.output.concentrate_pb'] + full['final.output.concentrate_sol']
full['rougher_input_feed_total'] = full['rougher.input.feed_au'] + full['rougher.input.feed_ag'] + full['rougher.input.feed_pb'] + full['rougher.input.feed_sol']
full['final_concentrate_total'] = full['final.output.concentrate_au'] + full['final.output.concentrate_ag'] + full['final.output.concentrate_pb'] + full['final.output.concentrate_sol']

# %%
# colors = ['#393E46', '#2BCDC1', '#F66095']
# group_labels = ["Флотация", "Сырье", "Финальная стадия"]

# hist_data = [
#     train['rougher_concentrate_total'],
#     train['rougher_input_feed_total'],
#     train['final_concentrate_total']
# ]


# fig = ff.create_distplot(hist_data,
#                          group_labels,
#                          colors=colors)
# fig.update_layout(title_text='Динамика изменения суммарной концентрации веществ',
#                   xaxis_title="Concentration",
#                   yaxis_title="Count",)
# fig.show();

# %% [markdown]
# Если зумировать график, можно четко увидеть что суммарные концентрации имеют распределения, близкие к нормальным после значения 35, а также пик возле 0 на выходе первичной очистки, что является аномалией. Проверим, можем ли эти данные безопасно удалить.

# %%
train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
to_remove = train.query('rougher_concentrate_total < 35 | rougher_input_feed_total < 35 | final_concentrate_total < 35')
to_remove_value = (to_remove.shape[0] / train.shape[0])
print(f'Данные к удалению составляют {to_remove_value:.2%} от обучающей выборки')
if to_remove_value < 10:
    print('Данные можно удалить')
else:
    print('Данных к удалению слишком много')
# Out:
# Данные к удалению составляют 4.93% от обучающей выборки
# Данные можно удалить

# %%
train = train.query('rougher_concentrate_total > 35 | rougher_input_feed_total > 35 | final_concentrate_total > 35')
train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Была изучена динамика изменений концентрации металлов (золото, серебро, свинец) на различных этапах очистки.
# Был сделан вывод, что концентрация золото ожидаемо растет с каждым этапом.
#
# 2. Был проведен сравнительный анализ распределения размеров гранул сырья на обучающей и тестовой выборках.
# Отличия незначительны.
#
# 3. Была исследована суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах, почле чего были удалены выбросы.

# %% [markdown]
# ## Построение модели

# %% [markdown]
# ### Выделение признаков

# %%
#ф-я для вычисления sMAPE и итоговой sMAPE

def smape(true, pred):
    return 100 / len(true) * np.sum(2 * np.abs(pred - true) / (np.abs(true) + np.abs(pred)))

def final_smape(smape_rougher, smape_final):
    return (0.25 * smape_rougher + 0.75 * smape_final)

# %% [markdown]
# Выбросим столбец `date_time`, мешающий модели и выделим целевые признаки: `rougher.output.recovery` и `final.output.recovery`

# %%
target_train_rougher = train['rougher.output.recovery']
target_train_final = train['final.output.recovery']

# %% [markdown]
# Удалим из тренировочной выборки признаки, отсутствующие в тестовой и подтянем из полной выборки в тестовую целевые признаки.

# %%
print('Признаки, отсутствующие в тестовой выборке')
print('_'*50)
count = 0
train_columns_to_drop = []
for col in train.columns:
    if col not in test.columns:
        print(col)
        count += 1
        train_columns_to_drop.append(col)
    else:
        pass
print('Всего отсутствующих признаков:', count)
# Out:
# Признаки, отсутствующие в тестовой выборке
# __________________________________________________
# final.output.concentrate_ag
# final.output.concentrate_pb
# final.output.concentrate_sol
# final.output.concentrate_au
# final.output.recovery
# final.output.tail_ag
# final.output.tail_pb
# final.output.tail_sol
# final.output.tail_au
# primary_cleaner.output.concentrate_ag
# primary_cleaner.output.concentrate_pb
# primary_cleaner.output.concentrate_sol
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.tail_ag
# primary_cleaner.output.tail_pb
# primary_cleaner.output.tail_sol
# primary_cleaner.output.tail_au
# rougher.calculation.sulfate_to_au_concentrate
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.au_pb_ratio
# rougher.output.concentrate_ag
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.concentrate_au
# rougher.output.recovery
# rougher.output.tail_ag
# ...

# %%
train.drop(columns=train_columns_to_drop, axis=1, inplace=True)

# %%
to_join = full[['rougher.output.recovery', 'final.output.recovery']]

# %%
test = test.join(to_join)
test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# Также добавим в тестовую выборку столбцы `rougher_concentrate_total`, `primary_cleaner_concentrate_total`, `final_concentrate_total`, на основании выбросов в этих столбцах очистим датафрейм, после чего снова удалим эти столбцы

# %%
full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
to_join_cleaner_columns = full[['rougher_concentrate_total', 'rougher_input_feed_total', 'final_concentrate_total']]

# %%
test = test.join(to_join_cleaner_columns)
test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
test = test.query('rougher_concentrate_total > 35 | rougher_input_feed_total > 35 | final_concentrate_total > 35')
train.shape
# Out:
# (14125, 53)

# %%
test.drop(columns = to_join_cleaner_columns, axis=1, inplace=True)
test.shape
# Out:
# (5220, 55)

# %%
target_test_rougher = test['rougher.output.recovery']
target_test_final = test['final.output.recovery']
features_test = test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)

# %%
train = train.join(to_join)
train.shape
# Out:
# (14125, 55)

# %%
features_train = train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
features_train.shape
# Out:
# (14125, 53)

# %%
features_test.shape
# Out:
# (5220, 53)

# %%
features_train.drop(columns='date', axis=1, inplace=True)
features_test.drop(columns='date', axis=1, inplace=True)

# %% [markdown]
# ### Проведем обучение моделей

# %%
rs = 1512

# %%
smape_score = make_scorer(smape, greater_is_better = False)

# %%
lasso = make_pipeline(StandardScaler(), Lasso())
rfr = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=rs))
dtr = make_pipeline(StandardScaler(), DecisionTreeRegressor(random_state=rs))
cbr = make_pipeline(StandardScaler(), CatBoostRegressor(random_state=rs))

# %%
models = [lasso, rfr, dtr, cbr]
model_names = ['lasso', 'rfr', 'dtr', 'cbr']

# %%
#выведем список параметров модели
for model, model_name in zip(models, model_names):
    print(model_name)
    display(model.get_params())
# Out:
# lasso
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()), ('lasso', Lasso())],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'lasso': Lasso(),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
#  'lasso__alpha': 1.0,
#  'lasso__copy_X': True,
#  'lasso__fit_intercept': True,
#  'lasso__max_iter': 1000,
#  'lasso__normalize': False,
#  'lasso__positive': False,
#  'lasso__precompute': False,
#  'lasso__random_state': None,
#  'lasso__selection': 'cyclic',
#  'lasso__tol': 0.0001,
#  'lasso__warm_start': False}
# rfr
# {'memory': None,
#  'steps': [('standardscaler', StandardScaler()),
#   ('randomforestregressor', RandomForestRegressor(random_state=1512))],
#  'verbose': False,
#  'standardscaler': StandardScaler(),
#  'randomforestregressor': RandomForestRegressor(random_state=1512),
#  'standardscaler__copy': True,
#  'standardscaler__with_mean': True,
#  'standardscaler__with_std': True,
# ...

# %%
lasso_parameters = {'lasso__alpha': [0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05]}

rfr_parameters = {'randomforestregressor__n_estimators': range(1, 101, 50),
                  'randomforestregressor__max_depth': range (5, 9)}

dtr_parameters = {'decisiontreeregressor__max_depth': range (1, 10)}

# %% [markdown]
# #### Catboost

# %%
grid = {'iterations': range(6, 8),
        'learning_rate': [0.1, 0.2, 0.3],
        'depth': [5, 6],
        'l2_leaf_reg': [1, 2]}

grid_cbr = GridSearchCV(estimator=CatBoostRegressor(), param_grid=grid, scoring=smape_score, cv=2, n_jobs=-1)
grid_cbr.fit(features_train, target_train_rougher)
# Out:
# 0:	learn: 13.3677881	total: 161ms	remaining: 805ms
# 1:	learn: 12.6900013	total: 173ms	remaining: 347ms
# 2:	learn: 12.2963950	total: 184ms	remaining: 184ms
# 3:	learn: 11.8865175	total: 196ms	remaining: 98.1ms
# 4:	learn: 11.5810323	total: 208ms	remaining: 41.6ms
# 5:	learn: 11.3478350	total: 219ms	remaining: 0us
# GridSearchCV(cv=2,
#              estimator=<catboost.core.CatBoostRegressor object at 0x000002264F62E070>,
#              n_jobs=-1,
#              param_grid={'depth': [5, 6], 'iterations': range(6, 8),
#                          'l2_leaf_reg': [1, 2],
#                          'learning_rate': [0.1, 0.2, 0.3]},
#              scoring=make_scorer(smape, greater_is_better=False))

# %%
display(abs(grid_cbr.best_score_))
display(grid_cbr.best_params_)
# Out:
# 11.651688203126353
# {'depth': 5, 'iterations': 6, 'l2_leaf_reg': 2, 'learning_rate': 0.3}

# %%
cbr_r = CatBoostRegressor(depth=5, iterations=6, l2_leaf_reg=2, learning_rate=0.3)
cbr_f = CatBoostRegressor(depth=7, iterations=6, l2_leaf_reg=2, learning_rate=0.3)

cbr_rougher = cbr_r.fit(features_train, target_train_rougher)
cbr_final = cbr_f.fit(features_train, target_train_final)

cbr_predictions_rougher = cbr_rougher.predict(features_train)
cbr_predictions_final = cbr_final.predict(features_train)
# Out:
# 0:	learn: 13.3677881	total: 7.74ms	remaining: 38.7ms
# 1:	learn: 12.6900013	total: 15ms	remaining: 30ms
# 2:	learn: 12.2963950	total: 22.3ms	remaining: 22.3ms
# 3:	learn: 11.8865175	total: 32.4ms	remaining: 16.2ms
# 4:	learn: 11.5810323	total: 39.5ms	remaining: 7.9ms
# 5:	learn: 11.3478350	total: 45.5ms	remaining: 0us
# 0:	learn: 9.3160642	total: 16.8ms	remaining: 83.8ms
# 1:	learn: 8.7208231	total: 30.9ms	remaining: 61.9ms
# 2:	learn: 8.3604158	total: 45.1ms	remaining: 45.1ms
# 3:	learn: 8.0584731	total: 59ms	remaining: 29.5ms
# 4:	learn: 7.8551876	total: 72.9ms	remaining: 14.6ms
# 5:	learn: 7.7025714	total: 87.6ms	remaining: 0us

# %%
print('Итоговый sMAPE модели CatBoost =', abs(grid_cbr.best_score_))
# Out:
# Итоговый sMAPE модели CatBoost = 11.651688203126353

# %% [markdown]
# #### Lasso

# %%
grid_rougher_lasso = RandomizedSearchCV(lasso, cv=5, param_distributions=lasso_parameters, scoring=smape_score, n_jobs=-1)
grid_final_lasso = RandomizedSearchCV(lasso, cv=5, param_distributions=lasso_parameters, scoring=smape_score, n_jobs=-1)

# %%
grid_rougher_lasso.fit(features_train,target_train_rougher)
grid_final_lasso.fit(features_train,target_train_final)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('standardscaler',
#                                               StandardScaler()),
#                                              ('lasso', Lasso())]),
#                    n_jobs=-1,
#                    param_distributions={'lasso__alpha': [0.02, 0.025, 0.03,
#                                                          0.035, 0.04, 0.045,
#                                                          0.05]},
#                    scoring=make_scorer(smape, greater_is_better=False))

# %%
abs(grid_rougher_lasso.best_score_)
# Out:
# 12.08190253868663

# %%
abs(grid_final_lasso.best_score_)
# Out:
# 11.100100762674746

# %%
print('Итоговый sMAPE модели Lasso =', abs(final_smape(grid_rougher_lasso.best_score_, grid_final_lasso.best_score_)))
# Out:
# Итоговый sMAPE модели Lasso = 11.345551206677719

# %% [markdown]
# #### RandomForestRegressor

# %%
grid_rougher_rfr = RandomizedSearchCV(rfr, cv=5, param_distributions=rfr_parameters,
                                            scoring=smape_score, n_jobs=-1)
grid_final_rfr = RandomizedSearchCV(rfr, cv=5, param_distributions=rfr_parameters,
                                          scoring=smape_score, n_jobs=-1)

# %%
grid_rougher_rfr.fit(features_train, target_train_rougher)
grid_final_rfr.fit(features_train, target_train_final)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('standardscaler',
#                                               StandardScaler()),
#                                              ('randomforestregressor',
#                                               RandomForestRegressor(random_state=1512))]),
#                    n_jobs=-1,
#                    param_distributions={'randomforestregressor__max_depth': range(5, 9),
#                                         'randomforestregressor__n_estimators': range(1, 101, 50)},
#                    scoring=make_scorer(smape, greater_is_better=False))

# %%
abs(grid_rougher_rfr.best_score_)
# Out:
# 10.865303262432933

# %%
abs(grid_final_rfr.best_score_)
# Out:
# 10.078634171421848

# %%
print('Итоговый sMAPE модели RandomForestRegressor =', abs(final_smape(grid_rougher_rfr.best_score_, grid_final_rfr.best_score_)))
# Out:
# Итоговый sMAPE модели RandomForestRegressor = 10.27530144417462

# %% [markdown]
# #### DecisionTreeRegressor

# %%
grid_rougher_dtr = RandomizedSearchCV(dtr, cv=10, param_distributions=dtr_parameters,
                                            scoring=smape_score, n_jobs=-1)
grid_final_dtr = RandomizedSearchCV(dtr, cv=10, param_distributions=dtr_parameters,
                                          scoring=smape_score, n_jobs=-1)

# %%
grid_rougher_dtr.fit(features_train, target_train_rougher)
grid_final_dtr.fit(features_train, target_train_final)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('standardscaler',
#                                               StandardScaler()),
#                                              ('decisiontreeregressor',
#                                               DecisionTreeRegressor(random_state=1512))]),
#                    n_jobs=-1,
#                    param_distributions={'decisiontreeregressor__max_depth': range(1, 10)},
#                    scoring=make_scorer(smape, greater_is_better=False))

# %%
abs(grid_rougher_dtr.best_score_)
# Out:
# 11.481975145262233

# %%
abs(grid_final_dtr.best_score_)
# Out:
# 10.174076823098266

# %%
print('Итоговый sMAPE модели DecisionTreeRegressor =', abs(final_smape(grid_rougher_dtr.best_score_, grid_final_dtr.best_score_)))
# Out:
# Итоговый sMAPE модели DecisionTreeRegressor = 10.501051403639257

# %% [markdown]
# Наилучшй результат с минимальным sMAPE = **10.27 у модели Случайного дерева**.<br>
# Протестируем модель

# %% [markdown]
# ### Тестирование модели

# %%
rfr_predictions_rougher = grid_rougher_rfr.predict(features_test)
rfr_predictions_final = grid_final_rfr.predict(features_test)

# %%
smape_r = smape(target_test_rougher, rfr_predictions_rougher)
smape_r
# Out:
# 13.978690174830293

# %%
smape_f = smape(target_test_final, rfr_predictions_final)
smape_f
# Out:
# 12.275486827059654

# %%
final_smape(smape_r, smape_f)
# Out:
# 12.701287664002313

# %% [markdown]
# Результат гораздо хуже, чем при валидации. Проверим также и бустинг на тестовой выборке

# %%
cbr_predictions_rougher = cbr_rougher.predict(features_test)
cbr_predictions_final = cbr_final.predict(features_test)

# %%
smape_r = smape(target_test_rougher, cbr_predictions_rougher)
smape_r
# Out:
# 11.960888721104588

# %%
smape_f = smape(target_test_final, rfr_predictions_final)
smape_f
# Out:
# 12.275486827059654

# %%
final_smape(smape_r, smape_f)
# Out:
# 12.196837300570888

# %% [markdown]
# Сравним нашу модель с константной

# %%
dummy_rougher = make_pipeline(StandardScaler(), DummyRegressor(strategy='mean'))
dummy_final = make_pipeline(StandardScaler(), DummyRegressor(strategy='mean'))

# %%
dummy_rougher.fit(features_train,target_train_rougher)
dummy_final.fit(features_train,target_train_final)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('dummyregressor', DummyRegressor())])

# %%
dummy_predictions_rougher = dummy_rougher.predict(features_test)
dummy_predictions_final = dummy_final.predict(features_test)

# %%
dummy_smape_r = smape(target_test_rougher, dummy_predictions_rougher)
dummy_smape_r
# Out:
# 11.544647385589675

# %%
dummy_smape_f = smape(target_test_final, dummy_predictions_final)
dummy_smape_f
# Out:
# 10.570421515505242

# %%
final_smape(dummy_smape_r, dummy_smape_f)
# Out:
# 10.81397798302635

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе исследования:
#
# * Изучены данные
# 3 датасета (разбитые на тренировочную и тестовую выборки, а также общая выборка)
# * Дубликатов в данных нет.
# * Обработаны пропуски (удалено допустимое количество,
# * Проведено сравнительное исследование 4 моделей. Модели оценивались по показателю sMAPE - симметричное среднее абсолютное процентное отклонение.
# Результаты следующие:
#     * **DecisionTreeRegressor: 14.4**,
#     * **RandomForestRegressor: 11.21**,
#     * **Lasso: 11.76**,
#     * **CatBoost: 11.29**
# * Лучше всего показала себя модель `RandomForestRegressor`, после чего сделали предсказание на тестовой выборке. Результат **12.2** против **10.8** на константной модели.

# %% [markdown]
# ☔☔☔
